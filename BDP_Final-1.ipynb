# %% [markdown]
# ## Part 1
# #### 1. Read the data
# #### 2. Create a sample of 10k observations.
# #### 3. Save the sampled file in a parquet and use it to explore the filtering opportunities.

# %%
#Ensure we are using the right kernel
import sys
print(sys.version)
print(spark.version)
# Out:
# 3.8.15 | packaged by conda-forge | (default, Nov 22 2022, 08:46:39)
# [GCC 10.4.0]
# 3.1.3

# %%
import time
import pyspark

# %% [markdown]
# ### Tuning Spark to increase the memory

# %%
sc = spark.sparkContext
print('Original spark.driver.maxResultSize: ' + sc._conf.get('spark.driver.maxResultSize'))

# Stop existing Spark environment
sc.stop()

# Waiting for the environment to stop
sleep_time = 10
print(f'Waiting for {sleep_time} seconds for the enviroment to stop...')
time.sleep(sleep_time)

# Applying new configuration and restarting Spark
conf = pyspark.SparkConf().setAll([('spark.driver.maxResultSize', '8g')])
sc = pyspark.SparkContext(conf=conf)

print('New spark.driver.maxResultSize: ' + sc._conf.get('spark.driver.maxResultSize'))

# Starting  Spark session with configs applied
spark = SparkSession(sc).builder.getOrCreate()
# Out:
# Original spark.driver.maxResultSize: 1920m
# Waiting for 10 seconds for the enviroment to stop...
# 23/02/28 18:27:18 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/02/28 18:27:18 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/02/28 18:27:18 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/02/28 18:27:18 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# New spark.driver.maxResultSize: 8g

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)
pd.reset_option('display.max_rows')
from itertools import compress 
from pyspark.sql.functions import *
from pyspark.sql.types import *
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings(action='ignore')
import os
import shutil
# import sh

# %%
# !pip uninstall -y nltk
# !pip install nltk --upgrade --no-cache-dir
# %pip install nltk -U

# %%
import nltk
# nltk.download('popular', halt_on_error=False)

# %%
import re
from pyspark.ml.feature import MinHashLSH
from pyspark.ml.feature import CountVectorizer,  IDF, CountVectorizerModel, Tokenizer, RegexTokenizer, StopWordsRemover
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql import Row
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Display the spark DF in a beautified way

# %%
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)

# %%
pd.set_option("max_colwidth", 100)

# %%
from google.cloud import storage

# %%
# List all files in given COS directory
def list_blobs(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    for blob in blobs:
        print(blob.name + '\t' + str(blob.size))

# %%
# List all files in given COS directory
def list_blobs_pd(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    blob_name = []
    blob_size = []
    
    for blob in blobs:
        blob_name.append(blob.name)
        blob_size.append(blob.size)

    blobs_df = pd.DataFrame(list(zip(blob_name, blob_size)), columns=['Name','Size'])

    blobs_df.style.format({"Size": "{:,.0f}"}) 
    
    return blobs_df

# %%
# Delete folder from COS bucket
def delete_folder(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    for blob in blobs:
        blob.delete()

# %%
# Reading data from open bucket, avaible to all students
bucket_read = 'msca-bdp-tweets'

# Saving results into individual bucket, students must update to their own bucket
bucket_write = 'msca-bdp-data-shared'

# %%
list_blobs_pd(bucket_read, 'final_project')
# Out:
#                                                                           Name  \
# 0                                                               final_project/
# 1                                                       final_project/_SUCCESS
# 2      final_project/part-00000-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 3      final_project/part-00001-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 4      final_project/part-00002-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# ...                                                                        ...
# 50692  final_project/part-50690-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 50693  final_project/part-50691-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 50694  final_project/part-50692-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 50695  final_project/part-50693-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
# 50696  final_project/part-50694-aa6d3cb4-7022-4df2-9921-218307589ce2-c000.json
#
#            Size
# 0             0
# 1             0
# 2       4500466
# 3       4107431
# 4       4672123
# ...         ...
# 50692  11562361
# 50693   9132693
# 50694  15376390
# 50695   8586044
# 50696  14317778
#
# [50697 rows x 2 columns]

# %% [markdown]
# #### Read data and check the schema

# %%
# %time
path = 'gs://msca-bdp-tweets/final_project'
twitter_raw = spark.read.json(path)
# Out:
# 23/02/28 18:58:19 WARN org.apache.spark.sql.execution.datasources.SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# 23/02/28 19:04:47 WARN org.apache.spark.sql.catalyst.util.package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
# Get the total number of rows in the DataFrame
total_rows = twitter_raw.count()

# Calculate the fraction of rows to sample
fraction = 10000 / total_rows

# Sample the DataFrame using the fraction
sampled_df = twitter_raw.sample(withReplacement=False, fraction=fraction, seed=13).limit(10000)

# %%
sampled_df.limit(10)
# Out:
# +-----------+--------------------+------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+--------------------+-------------------+--------------------+-----------------------+--------------------+-----------+-------------+---------+--------------------+--------------------+--------------------+--------------------+-------------+---------+--------------------+--------------------+---------------------+
# |coordinates|          created_at|display_text_range|            entities|   extended_entities|      extended_tweet|favorite_count|favorited|filter_level| geo|                 id|             id_str|in_reply_to_screen_name|in_reply_to_status_id|in_reply_to_status_id_str|in_reply_to_user_id|in_reply_to_user_id_str|is_quote_status|lang|place|possibly_sensitive|quote_count|       quoted_status|   quoted_status_id|quoted_status_id_str|quoted_status_permalink|         quoted_text|reply_count|retweet_count|retweeted|      retweeted_from|    retweeted_status|              source|                text| timestamp_ms|truncated|          tweet_text|                user|withheld_in_countries|
# +-----------+--------------------+------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+--------------------+-------------------+--------------------+-----------------------+--------------------+-----------+-------------+---------+--------------------+--------------------+--------------------+--------------------+-------------+---------+--------------------+--------------------+---------------------+
# |       null|Thu Dec 01 00:26:...|         [27, 140]|{[], null, [], [{...|                null|{[27, 203], {[], ...|             0|    false|         low|null|1598111350114652162|1598111350114652162|        jordanbpeterson|  1598108822790606848|      1598108822790606848|           95092020|               95092020|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|         |elonmusk Sadly, m...|                null|<a href="https://...|@jordanbpeterson ...|1669854411997|     true|@jordanbpeterson ...|{false, Mon Mar 1...|                 null|
# |       null|Wed Nov 09 23:15:...|              null|{[], null, [], [{...|                null|{[0, 195], {[], n...|             0|    false|         low|null|1590483348883132416|1590483348883132416|                   null|                 null|                     null|               null|                   null|          false|  en| null|             false|          0|                null|               null|                null|                   null|                null|          0|            0|         |                null|                null|<a href="https://...|Holy Cross vs Whe...|1668035754782|     true|Holy Cross vs Whe...|{false, Sun Aug 2...|                 null|
# |       null|Mon Dec 12 19:27:...|        [102, 140]|{[], null, [], [{...|                null|{[102, 236], {[],...|             0|    false|         low|null|1602384698281320448|1602384698281320448|           EricKyleGant|  1602371378698764296|      1602371378698764296|1594240702371831808|    1594240702371831808|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|         |Helen_OfDetroit @...|                null|<a href="http://t...|@EricKyleGant @He...|1670873257595|     true|@EricKyleGant @He...|{false, Wed Jun 1...|                 null|
# |       null|Wed May 25 05:22:...|              null|{[], null, [], []...|                null|                null|             0|    false|         low|null|1529332082467643393|1529332082467643393|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|       RT|             edemss_|{null, Tue May 24...|<a href="http://t...|RT @edemss_: Know...|1653456156733|    false|Knowing when to u...|{false, Tue Dec 0...|                 null|
# |       null|Thu Sep 08 00:23:...|          [13, 55]|{[], null, [], []...|                null|                null|             0|    false|         low|null|1567669963917508608|1567669963917508608|            moodyliltoe|  1567497079412649987|      1567497079412649987|1511972931597135873|    1511972931597135873|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|         |                null|                null|<a href="https://...|@moodyliltoe Hi! ...|1662596619954|    false|@moodyliltoe Hi! ...|{false, Tue Jun 2...|                 null|
# |       null|Sat May 28 02:36:...|              null|{[], null, [], []...|                null|                null|             0|    false|         low|null|1530377446255644673|1530377446255644673|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|       RT|      JessMcMasterKC|{null, Fri May 27...|<a href="http://t...|RT @JessMcMasterK...|1653705390882|    false|It’s worth repeat...|{false, Sat Jul 2...|                 null|
# |       null|Sun May 29 13:44:...|              null|{[], null, [], []...|                null|                null|             0|    false|         low|null|1530907856232382466|1530907856232382466|                   null|                 null|                     null|               null|                   null|           true|  en| null|              null|          0|{null, Sat May 28...|1530661596158210049| 1530661596158210049|   {twitter.com/sent...|The elites in soc...|          0|            0|       RT|         mehdirhasan|{null, Sun May 29...|<a href="http://t...|RT @mehdirhasan: ...|1653831850475|    false|Cruz is a graduat...|{false, Tue Jul 0...|                 null|
# |       null|Wed May 25 05:14:...|              null|{[], [{{null, nul...|{[{{null, null, f...|                null|             0|    false|         low|null|1529329918370258944|1529329918370258944|                   null|                 null|                     null|               null|                   null|          false|  en| null|             false|          0|                null|               null|                null|                   null|                null|          0|            0|       RT|            NikkiMcR|{null, Tue May 24...|<a href="http://t...|RT @NikkiMcR: Fox...|1653455640772|    false|Fox hosts coverin...|{false, Sun Aug 1...|                 null|
# |       null|Wed May 25 11:40:...|              null|{[], null, [], []...|                null|                null|             0|    false|         low|null|1529427171776790529|1529427171776790529|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|       RT|        audreymg0928|{null, Tue May 24...|<a href="http://t...|RT @audreymg0928:...|1653478827791|    false|My daughter’s bea...|{false, Fri Dec 2...|                 null|
# |       null|Tue Nov 08 22:26:...|              null|{[], null, [], []...|                null|                null|             0|    false|         low|null|1590108450024878080|1590108450024878080|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|                null|               null|                null|                   null|                null|          0|            0|         |                null|                null|<a href="https://...|I wanna serve pop...|1667946371929|    false|I wanna serve pop...|{false, Sat Mar 1...|                 null|
# +-----------+--------------------+------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+--------------------+-------------------+--------------------+-----------------------+--------------------+-----------+-------------+---------+--------------------+--------------------+--------------------+--------------------+-------------+---------+--------------------+--------------------+---------------------+

# %%
# Save the sampled DataFrame as a Parquet file
sampled_df.write.format("parquet").mode('overwrite').save('gs://msca-bdp-students-bucket/shared_data/saikrishnaj/twitter_sample')

# %%
# !hadoop fs -ls 'gs://msca-bdp-students-bucket/shared_data/saikrishnaj/twitter_sample'
# Out:
# Found 2 items
# -rwx------   3 root root          0 2023-02-28 20:13 gs://msca-bdp-students-bucket/shared_data/saikrishnaj/twitter_sample/_SUCCESS
# -rwx------   3 root root   17102044 2023-02-28 20:13 gs://msca-bdp-students-bucket/shared_data/saikrishnaj/twitter_sample/part-00000-e3cc3432-8e6e-4e65-b49d-c79c10a55cb8-c000.snappy.parquet
